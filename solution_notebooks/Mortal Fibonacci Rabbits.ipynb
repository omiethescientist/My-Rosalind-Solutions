# %%
def FibRabbits(I_0, M_0, k, n_0, m, mem):
  if len(mem) >= m:
    D = mem[-m]
  else:
    D = 0
  I = M_0*k
  M = M_0+I_0-D
  n = n_0 - 1
  if n == 1:
    return I + M
  else:
    mem.append(I)
    return FibRabbits(I, M, k, n, m, mem)

# %%
FibRabbits(1, 0, 1, 91, 18, [1])
# Out:
# 4633115987862944434
