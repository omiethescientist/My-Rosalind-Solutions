# %%
import numpy as np

# %%
string = "19005 19553 18824 16215 16984 16157"

# %%
pop_array = np.matrix(string.split()).astype(float)
prob_array = np.matrix([1.0,1.0,1.0,0.75,0.5,0.0])

# %%
np.matmul(prob_array, pop_array.T)*2
# Out:
# matrix([[156070.5]])
