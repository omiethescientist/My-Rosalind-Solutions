# %%
def FibRabbits(I_0, M_0, k, n_0):
  I = M_0*k
  M = M_0+I_0
  n = n_0 - 1
  if n == 1:
    return I + M
  else:
    return FibRabbits(I, M, k, n)

# %%
FibRabbits(1, 0, 3, 30)
# Out:
# 20444528200
