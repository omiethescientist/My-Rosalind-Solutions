# %%
string = "..."

# %%
def revComp(string):
  revString = string[::-1]
  dnaDict = {"A":"T", "G":"C", "C":"G", "T":"A"}
  revCompList = [dnaDict[i] for i in revString]
  return "".join(revCompList)

# %%
revComp(string)
# Out:
# '...'
