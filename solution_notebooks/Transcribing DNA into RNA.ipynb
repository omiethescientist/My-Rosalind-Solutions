# %%
string = "..."

# %%
def dna2rna(string):
  rnaDict = {"A":"A", "G":"G", "C":"C", "T":"U"}
  rnaList = [rnaDict[i] for i in string]
  return "".join(rnaList)

# %%
dna2rna(string)
# Out:
# '...'
